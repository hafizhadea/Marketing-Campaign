# %%
import pandas as pd

facebookpage = pd.read_csv(r'/Users/empty/Documents/Practice Python/dataset_facebook.csv',sep=';')

# %%
facebookpage.head()
# Out:
#    Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0            139441   Photo         2          12             4          3
# 1            139441  Status         2          12             3         10
# 2            139441   Photo         3          12             3          3
# 3            139441   Photo         2          12             2         10
# 4            139441   Photo         2          12             2          3
#
#    Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 0   0.0                       2752                             5091
# 1   0.0                      10460                            19057
# 2   0.0                       2413                             4373
# 3   1.0                      50128                            87991
# 4   0.0                       7244                            13594
#
#    Lifetime Engaged Users  Lifetime Post Consumers  \
# ...

# %%
week_subscribers = facebookpage.groupby(['Post Weekday'],sort=False)['Lifetime Engaged Users'].nunique()
week_subscribers.plot(kind='bar')

# %%
impressions_sorted = facebookpage.sort_values("Lifetime Post Total Impressions")

print(impressions_sorted.tail(10))
# Out:
#      Page total likes   Type  Category  Post Month  Post Weekday  Post Hour  \
# 140            136013   Link         1          10             4          3
# 380            111620  Photo         1           4             7         14
# 227            131728  Photo         1           7             4         10
# 277            126424  Video         1           6             2         13
# 244            130791  Photo         2           7             3          5
# 464             92079  Photo         1           2             6         13
# 437            100732  Photo         1           3             6         10
# 463             92186  Photo         3           2             7          2
# 460             92507  Photo         3           2             1         13
# 415            104070  Photo         1           3             4          7
#
#      Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# ...

# %%
print(facebookpage['comment'])
# Out:
# 0       4
# 1       5
# 2       0
# 3      58
# 4      19
#        ..
# 495     5
# 496     0
# 497     4
# 498     7
# 499     0
# Name: comment, Length: 500, dtype: int64

# %%
# Post that have more than 10 comments

print(facebookpage['comment'] > 10)
# Out:
# 0      False
# 1      False
# 2      False
# 3       True
# 4       True
#        ...
# 495    False
# 496    False
# 497    False
# 498    False
# 499    False
# Name: comment, Length: 500, dtype: bool
#      Page total likes   Type  Category  Post Month  Post Weekday  Post Hour  \
# 3              139441  Photo         2          12             2         10
# 4              139441  Photo         2          12             2          3
# 17             138414  Photo         1          12             2         12
# 28             138895  Photo         2          12             5          3
# 29             138895  Video         1          12             4         11
# ..                ...    ...       ...         ...           ...        ...
# 460             92507  Photo         3           2             1         13
# 462             92293  Photo         3           2             7         13
# 480             86909  Photo         2           1             4         11
# ...

# %%
print(facebookpage[facebookpage['comment'] > 10])
# Out:
#      Page total likes   Type  Category  Post Month  Post Weekday  Post Hour  \
# 3              139441  Photo         2          12             2         10
# 4              139441  Photo         2          12             2          3
# 17             138414  Photo         1          12             2         12
# 28             138895  Photo         2          12             5          3
# 29             138895  Video         1          12             4         11
# ..                ...    ...       ...         ...           ...        ...
# 460             92507  Photo         3           2             1         13
# 462             92293  Photo         3           2             7         13
# 480             86909  Photo         2           1             4         11
# 488             85979  Photo         3           1             7         10
# 493             85093  Photo         3           1             1          2
#
# ...

# %%
# Most commented post
top_comments = facebookpage.sort_values("comment", ascending=False)
print(top_comments.head(5))
# Out:
#      Page total likes   Type  Category  Post Month  Post Weekday  Post Hour  \
# 244            130791  Photo         2           7             3          5
# 460             92507  Photo         3           2             1         13
# 168            135428  Photo         1           9             3         10
# 288            126141  Photo         1           6             4         12
# 228            131728  Photo         2           7             4          3
#
#      Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 244   1.0                     180480                           319133
# 460   0.0                      55520                           665792
# 168   0.0                      41984                            68290
# 288   0.0                      20896                            29062
# 228   0.0                      14824                            21863
#
#      Lifetime Engaged Users  Lifetime Post Consumers  \
# ...
